# %%
using Gadfly
using Distributions
using GLM
using HypothesisTests
using StatPlots
using DataFrames
# Out:
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/bradley/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at /Users/bradley/.julia/v0.4/DataArrays/src/operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/bradley/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at /Users/bradley/.julia/v0.4/DataArrays/src/operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: Method definition partitions(Integer) in module Base at combinatorics.jl:252 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:26.
# WARNING: Method definition partitions(Integer, Integer) in module Base at combinatorics.jl:318 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:93.
# WARNING: Method definition partitions(AbstractArray{T<:Any, 1}) in module Base at combinatorics.jl:380 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:158.
# WARNING: Method definition partitions(AbstractArray{T<:Any, 1}, Int64) in module Base at combinatorics.jl:447 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:228.
# WARNING: Method definition factorial(#T<:Integer, #T<:Integer) in module Base at combinatorics.jl:56 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/factorials.jl:18.
# WARNING: Method definition factorial(Integer, Integer) in module Base at combinatorics.jl:66 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/factorials.jl:28.
# WARNING: Method definition levicivita(AbstractArray{#T<:Integer, 1}) in module Base at combinatorics.jl:611 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:188.
# WARNING: Method definition nthperm(AbstractArray{#T<:Integer, 1}) in module Base at combinatorics.jl:92 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:161.
# WARNING: Method definition nthperm(AbstractArray{T<:Any, 1}, Integer) in module Base at combinatorics.jl:89 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:157.
# WARNING: Method definition combinations(Any, Integer) in module Base at combinatorics.jl:182 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/combinations.jl:42.
# WARNING: Method definition prevprod(Array{Int64, 1}, Any) in module Base at combinatorics.jl:565 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:354.
# WARNING: Method definition nthperm!(AbstractArray{T<:Any, 1}, Integer) in module Base at combinatorics.jl:70 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:136.
# WARNING: Method definition parity(AbstractArray{#T<:Integer, 1}) in module Base at combinatorics.jl:642 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:221.
# WARNING: Method definition permutations(Any) in module Base at combinatorics.jl:219 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:24.

# %%
#Gadfly is a plotting package for statistical applications.
Pkg.add("Cairo");
using Cairo;
# Out:
# INFO: No packages to install, update or remove
# INFO: Package database updated
# INFO: Precompiling module Cairo...
# ERROR: LoadError: Cairo not properly installed. Please run
# Pkg.build("Cairo")
#  in error at error.jl:22
#  in include at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in include_from_node1 at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  [inlined code] from none:2
#  in anonymous at no file:0
#  in process_options at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in _start at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
# while loading /Users/bradley/.julia/v0.4/Cairo/src/Cairo.jl, in expression starting on line 8
# LoadError: Failed to precompile Cairo to /Users/bradley/.julia/lib/v0.4/Cairo.ji
# while loading In[1], in expression starting on line 3
#
#  in error at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in compilecache at loading.jl:400
#  in require at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib

# %%
xvals = rand(1:5, 5)
# Out:
# 5-element Array{Int64,1}:
#  1
#  3
#  2
#  4
#  3

# %%
yvals = rand(1:5, 5)
# Out:
# 5-element Array{Int64,1}:
#  5
#  2
#  1
#  3
#  5

# %%
using Distributions
using GLM
using StatPlots
using HypothesisTests
using Cairo
using Gadfly
# Out:
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/bradley/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at /Users/bradley/.julia/v0.4/DataArrays/src/operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/bradley/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at /Users/bradley/.julia/v0.4/DataArrays/src/operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: Method definition partitions(Integer) in module Base at combinatorics.jl:252 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:26.
# WARNING: Method definition partitions(Integer, Integer) in module Base at combinatorics.jl:318 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:93.
# WARNING: Method definition partitions(AbstractArray{T<:Any, 1}) in module Base at combinatorics.jl:380 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:158.
# WARNING: Method definition partitions(AbstractArray{T<:Any, 1}, Int64) in module Base at combinatorics.jl:447 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:228.
# WARNING: Method definition factorial(#T<:Integer, #T<:Integer) in module Base at combinatorics.jl:56 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/factorials.jl:18.
# WARNING: Method definition factorial(Integer, Integer) in module Base at combinatorics.jl:66 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/factorials.jl:28.
# WARNING: Method definition levicivita(AbstractArray{#T<:Integer, 1}) in module Base at combinatorics.jl:611 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:188.
# WARNING: Method definition nthperm(AbstractArray{#T<:Integer, 1}) in module Base at combinatorics.jl:92 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:161.
# WARNING: Method definition nthperm(AbstractArray{T<:Any, 1}, Integer) in module Base at combinatorics.jl:89 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:157.
# WARNING: Method definition combinations(Any, Integer) in module Base at combinatorics.jl:182 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/combinations.jl:42.
# WARNING: Method definition prevprod(Array{Int64, 1}, Any) in module Base at combinatorics.jl:565 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/partitions.jl:354.
# WARNING: Method definition nthperm!(AbstractArray{T<:Any, 1}, Integer) in module Base at combinatorics.jl:70 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:136.
# WARNING: Method definition parity(AbstractArray{#T<:Integer, 1}) in module Base at combinatorics.jl:642 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:221.
# WARNING: Method definition permutations(Any) in module Base at combinatorics.jl:219 overwritten in module Combinatorics at /Users/bradley/.julia/v0.4/Combinatorics/src/permutations.jl:24.
# INFO: Precompiling module Cairo...
# ERROR: LoadError: Cairo not properly installed. Please run
# Pkg.build("Cairo")
#  in error at error.jl:22
#  in include at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in include_from_node1 at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  [inlined code] from none:2
#  in anonymous at no file:0
#  in process_options at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in _start at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
# while loading /Users/bradley/.julia/v0.4/Cairo/src/Cairo.jl, in expression starting on line 8
# LoadError: Failed to precompile Cairo to /Users/bradley/.julia/lib/v0.4/Cairo.ji
# while loading In[6], in expression starting on line 5
#
#  in error at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in compilecache at loading.jl:400
#  in require at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib

# %%
Pkg.build("Cairo")
# Out:
# INFO: Building Homebrew
# Already up-to-date.
# INFO: Building Cairo
# ==> Installing gobject-introspection from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/gobject-introspection-1.50.0.sierra.bottle.tar.gz
# Already downloaded: /Users/bradley/Library/Caches/Homebrew.jl/gobject-introspection-1.50.0.sierra.bottle.tar.gz
# ==> Pouring gobject-introspection-1.50.0.sierra.bottle.tar.gz
# 🍺  /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/gobject-introspection/1.50.0: 172 files, 9.6M
# Warning: Already linked: /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/gobject-introspection/1.50.0
# ==> Installing harfbuzz from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/harfbuzz-1.3.3_1.sierra.bottle.1.tar.gz
# ==> Pouring harfbuzz-1.3.3_1.sierra.bottle.1.tar.gz
# 🍺  /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/harfbuzz/1.3.3_1: 132 files, 4.5M
# Warning: Already linked: /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/harfbuzz/1.3.3_1
# ==> Installing pango from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/pango-1.40.3.sierra.bottle.tar.gz
# ==> Pouring pango-1.40.3.sierra.bottle.tar.gz
# 🍺  /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/pango/1.40.3: 125 files, 5.1M
# Warning: Already linked: /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/pango/1.40.3

# %%
using Cairo
# Out:
# INFO: Precompiling module Cairo...

# %%
using DataFrames
using Gadfly
# Out:
# WARNING: using Gadfly.plot in module Main conflicts with an existing identifier.

# %%
Gadfly.plot(x = xvals, y = yvals)
# Out:
# Plot(...)

# %%
Gadfly.plot(x = xvals, y = yvals, Geom.point)
# Out:
# Plot(...)

# %%
xvals2 = rand(0:100, 100)
yvals2 = rand(0:100, 100)
# Out:
# 100-element Array{Int64,1}:
#  70
#  22
#   9
#  26
#  15
#  94
#  95
#  50
#  84
#  18
#  10
#  32
#  52
#   ⋮
#  88
#  82
#  72
#  29
#  41
#  74
#  98
#  53
#  15
#  34
#  19
#  71

# %%
Gadfly.plot(x = sort(xvals2), y = sort(yvals2))
# Out:
# Plot(...)

# %%
Gadfly.plot(x = xvals2, y = yvals2, Geom.point, Geom.line)
# Out:
# Plot(...)

# %%
Gadfly.plot(x = xvals2, y = yvals2, Geom.point, Geom.smooth(method = :lm))
# Out:
# Plot(...)

# %%
Gadfly.plot(layer(x = xvals2, y = yvals2, Geom.point), layer(x = sort(xvals2), y = sort(yvals2), Geom.point))
# Out:
# Plot(...)

# %%
Gadfly.plot(layer(x = xvals2, y = yvals2, Geom.point),
layer(x = sort(xvals2), y = sort(yvals2), Geom.point, Theme(default_color = colorant"orange")))
# Out:
# Plot(...)

# %%
points1 = layer(x = xvals2, y = yvals2, Geom.point, Theme(default_color = colorant"deepskyblue"))
points2 = layer(x = sort(xvals2), y = sort(yvals2), Geom.point, Theme(default_color = colorant"orange"))
Gadfly.plot(points1, points2, Guide.manual_color_key("Legend for this plot",
["Set of points", "Sorted set of points"], ["deepskyblue", "orange"]))
# Out:
# Plot(...)

# %%
Gadfly.plot(layer(x = xvals2, y = yvals2, Geom.point),
layer(x = sort(xvals2), y = sort(yvals2), Geom.point, Theme(default_color = colorant"orange")),
Theme(grid_color = colorant"white"))
# Out:
# Plot(...)

# %%
Gadfly.plot(layer(x = xvals2, y = yvals2, Geom.point),
layer(x = sort(xvals2), y = sort(yvals2), Geom.point, Theme(default_color = colorant"orange")),
Theme(grid_color = colorant"white", grid_color_focused = colorant"white"))
# Out:
# Plot(...)

# %%
Gadfly.plot(x = xvals2, y = yvals2, Geom.point, Geom.smooth(method = :lm), Theme(line_width = 4Gadfly.px))
# Out:
# LoadError: UndefVarError: xvals2 not defined
# while loading In[1], in expression starting on line 1

# %%
using Gadfly
using DataFrames
using Distributions
# Out:
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/bradley/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.DataArray, AbstractArray) at /Users/bradley/.julia/v0.4/DataArrays/src/operators.jl:276.
# To fix, define
#     +(DataArrays.DataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.
# WARNING: New definition
#     +(AbstractArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury) at /Users/bradley/.julia/v0.4/WoodburyMatrices/src/SymWoodburyMatrices.jl:106
# is ambiguous with:
#     +(DataArrays.AbstractDataArray, AbstractArray) at /Users/bradley/.julia/v0.4/DataArrays/src/operators.jl:300.
# To fix, define
#     +(DataArrays.AbstractDataArray{T<:Any, 2}, WoodburyMatrices.SymWoodbury)
# before the new definition.

# %%
xvals = rand(1:5, 5)
yvals = rand(1:5, 5)
xvals2 = rand(1:100, 100)
yvals2 = rand(1:100, 100)
# Out:
# 100-element Array{Int64,1}:
#  85
#  93
#   8
#  57
#  29
#  25
#  65
#  64
#  99
#  57
#  24
#  66
#  89
#   ⋮
#  20
#  95
#  37
#  70
#   6
#   9
#  86
#  27
#  85
#   2
#  49
#  90

# %%
plot(x = xvals, y = yvals)
# Out:
# Plot(...)

# %%
plot(x = sort(xvals), y = sort(yvals), Geom.point,
Guide.title("My scatter plot"),
Guide.xlabel("X Values"), Guide.ylabel("y values"))
# Out:
# Plot(...)

# %%
draw(PNG("myqqplot.png", 8inch, 6inch),
plot(x = rand(Normal(), 100), y = Normal(), Stat.qq, Geom.point, Guide.title("QQ plot")))
# Out:
# LoadError: Cairo and Fontconfig are necessary for the PNG backend. Run:
#   Pkg.add("Cairo")
#   Pkg.add("Fontconfig")
# You also have to delete /Users/bradley/.julia/lib/v0.4/Compose.ji
# and restart your REPL session afterwards.
#
# while loading In[9], in expression starting on line 1
#
#  in PNG at /Users/bradley/.julia/v0.4/Compose/src/Compose.jl:182

# %%
using Cairo

# %%
draw(PNG("myqqplot.png", 8inch, 6inch),
plot(x = rand(Normal(), 100), y = Normal(), Stat.qq, Geom.point, Guide.title("QQ plot")))
# Out:
# LoadError: Cairo and Fontconfig are necessary for the PNG backend. Run:
#   Pkg.add("Cairo")
#   Pkg.add("Fontconfig")
# You also have to delete /Users/bradley/.julia/lib/v0.4/Compose.ji
# and restart your REPL session afterwards.
#
# while loading In[11], in expression starting on line 1
#
#  in PNG at /Users/bradley/.julia/v0.4/Compose/src/Compose.jl:182

# %%
Pkg.add("Fontconfig")
# Out:
# INFO: Cloning cache of Fontconfig from git://github.com/dcjones/Fontconfig.jl.git
# INFO: Installing Fontconfig v0.1.1
# INFO: Building Homebrew
# Updated 2 taps (homebrew/core, homebrew/science).
# ==> New Formulae
# gst-rtsp-server
# homebrew/science/libeemd
# homebrew/science/sollya
# termius
# tomcat@6
# tomcat@7
# ==> Updated Formulae
# artifactory
# aws-elasticbeanstalk
# aws-sdk-cpp
# awscli
# babl
# bazel
# chromedriver
# closure-compiler
# clutter-gst
# crystal-lang
# devd
# docker-machine-driver-xhyve
# dockviz
# dovecot
# efl
# eigen
# elasticsearch
# exploitdb
# filebeat
# fluent-bit
# fonttools
# freetds
# gimme
# gnutls
# grafana
# gst-libav
# hadolint
# harfbuzz
# heroku
# homebank
# homebrew/science/g2o
# homebrew/science/hlaminer
# homebrew/science/megahit
# homebrew/science/muscle
# homebrew/science/nextflow
# homebrew/science/pathvisio
# homebrew/science/pear
# homebrew/science/r-gui
# homebrew/science/sratoolkit
# homebrew/science/statismo
# homebrew/science/vsearch
# homebrew/science/vtk
# httpie
# ibex
# imagemagick
# imapfilter
# influxdb
# iso-codes
# jadx
# jasper
# javarepl
# jsonschema2pojo
# kobalt
# libphonenumber
# libvirt
# llnode
# macvim
# mawk
# mdv
# metabase
# micro
# neofetch
# node
# node-build
# node@4
# node@6
# nsd
# ola
# openvpn
# pandoc-crossref
# pick
# pigz
# pkcs11-helper
# platformio
# pre-commit
# rancher-cli
# rancher-compose
# redis
# riemann
# scamper
# shared-mime-info
# sjk
# sourcekitten
# tag
# td
# terragrunt
# tomcat
# vault
# vowpal-wabbit
# wakatime-cli
# wavpack
# yarn
# yle-dl
# youtube-dl
# zplug
# ==> Deleted Formulae
# pdksh
# Uninstalling harfbuzz... (132 files, 4.5M)
# ==> Installing harfbuzz from staticfloat/juliatranslated
# ==> Downloading https://homebrew.bintray.com/bottles/harfbuzz-1.3.4.sierra.bottle.tar.gz
# ==> Pouring harfbuzz-1.3.4.sierra.bottle.tar.gz
# 🍺  /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/harfbuzz/1.3.4: 132 files, 4.5M
# Warning: Already linked: /Users/bradley/.julia/v0.4/Homebrew/deps/usr/Cellar/harfbuzz/1.3.4
# INFO: Building Fontconfig
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of Fontconfig
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
;pwd
# Out:
# /Users/bradley/Desktop/Julia

# %%
;ls
# Out:
# #test_script.jl#
# Coursera Week 4.ipynb
# Data Visualization.ipynb
# Gadfly Practice.ipynb
# JuliaCourseNotebooks
# MTH 281 Test 3 Rogowski Examaples.docx
# Peer+Review.html
# QuantEcon.applications
# Untitled1.ipynb
# Week 4 - Working with data.ipynb
# _51ec14aa4889236a8be2cb609bd131ac_Week4_PR_Template.zip
# jl-quant-econ.pdf
# newfile.txt
# quant.ipynb
# test_script.jl
# us_cities.txt

# %%
;cd ./JuliaCourseNotebooks
# Out:
# /Users/bradley/Desktop/Julia/JuliaCourseNotebooks

# %%
;ls
# Out:
# Julia_Week1
# Julia_Week2
# Julia_Week3
# Julia_Week4

# %%
;cd ./Julia_Week4
# Out:
# /Users/bradley/Desktop/Julia/JuliaCourseNotebooks/Julia_Week4

# %%
;ls
# Out:
# CCS.csv
# Data Frames practice.ipynb
# GadflyTutorialData.csv
# Week4_1Collections.ipynb
# Week4_2Functions.ipynb
# Week4_3DataFrames.ipynb
# Week4_4Data.ipynb
# Week4_Honors2-Gadfly.ipynb
# data1.csv
# functions recap.ipynb
# style.css

# %%
data = readtable("GadflyTutorialData.csv")
# Out:
# 200×10 DataFrames.DataFrame
# │ Row │ Patient │ Gender │ Age │ Variable1 │ Variable2 │ Variable3 │ Variable4 │
# ├─────┼─────────┼────────┼─────┼───────────┼───────────┼───────────┼───────────┤
# │ 1   │ 1       │ "F"    │ 37  │ 22.3      │ 104       │ 5.3       │ 64        │
# │ 2   │ 2       │ "F"    │ 55  │ 12.1      │ 84        │ 12.7      │ 58        │
# │ 3   │ 3       │ "M"    │ 44  │ 15.6      │ 101       │ 6.9       │ 68        │
# │ 4   │ 4       │ "F"    │ 54  │ 20.8      │ 111       │ 14.8      │ 54        │
# │ 5   │ 5       │ "M"    │ 41  │ 21.5      │ 106       │ 25.1      │ 50        │
# │ 6   │ 6       │ "F"    │ 51  │ 14.7      │ 112       │ 14.1      │ 70        │
# │ 7   │ 7       │ "M"    │ 42  │ 18.7      │ 99        │ 0.3       │ 63        │
# │ 8   │ 8       │ "M"    │ 50  │ 22.1      │ 102       │ 5.7       │ 62        │
# │ 9   │ 9       │ "M"    │ 50  │ 11.6      │ 114       │ 12.0      │ 64        │
# │ 10  │ 10      │ "F"    │ 55  │ 18.9      │ 107       │ 7.8       │ 54        │
# │ 11  │ 11      │ "F"    │ 37  │ 9.5       │ 109       │ 12.8      │ 58        │
# ⋮
# │ 189 │ 189     │ "M"    │ 37  │ 17.8      │ 104       │ 2.1       │ 52        │
# │ 190 │ 190     │ "F"    │ 54  │ 11.8      │ 92        │ 0.6       │ 66        │
# │ 191 │ 191     │ "F"    │ 54  │ 23.6      │ 93        │ 6.3       │ 51        │
# │ 192 │ 192     │ "F"    │ 47  │ 13.5      │ 99        │ 0.1       │ 70        │
# │ 193 │ 193     │ "M"    │ 42  │ 16.0      │ 108       │ 1.7       │ 51        │
# │ 194 │ 194     │ "F"    │ 53  │ 14.3      │ 96        │ 7.7       │ 58        │
# │ 195 │ 195     │ "M"    │ 54  │ 9.7       │ 100       │ 1.3       │ 55        │
# │ 196 │ 196     │ "F"    │ 40  │ 9.6       │ 103       │ 12.1      │ 56        │
# │ 197 │ 197     │ "M"    │ 42  │ 12.6      │ 109       │ 3.6       │ 68        │
# │ 198 │ 198     │ "M"    │ 49  │ 11.2      │ 95        │ 1.8       │ 53        │
# │ 199 │ 199     │ "M"    │ 36  │ 24.2      │ 97        │ 8.2       │ 58        │
# │ 200 │ 200     │ "F"    │ 48  │ 10.3      │ 114       │ 20.4      │ 63        │
#
# │ Row │ Category1 │ Category2 │ Category3 │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ "A"       │ "C"       │ "P"       │
# │ 2   │ "B"       │ "X"       │ "Q"       │
# │ 3   │ "A"       │ "R"       │ "Q"       │
# │ 4   │ "B"       │ "C"       │ "R"       │
# │ 5   │ "A"       │ "X"       │ "P"       │
# │ 6   │ "B"       │ "R"       │ "R"       │
# │ 7   │ "A"       │ "C"       │ "P"       │
# │ 8   │ "B"       │ "X"       │ "R"       │
# │ 9   │ "A"       │ "R"       │ "P"       │
# │ 10  │ "B"       │ "C"       │ "P"       │
# │ 11  │ "A"       │ "X"       │ "Q"       │
# ⋮
# │ 189 │ "A"       │ "X"       │ "R"       │
# │ 190 │ "B"       │ "R"       │ "P"       │
# │ 191 │ "A"       │ "C"       │ "P"       │
# │ 192 │ "B"       │ "X"       │ "Q"       │
# │ 193 │ "A"       │ "R"       │ "Q"       │
# │ 194 │ "B"       │ "C"       │ "R"       │
# │ 195 │ "A"       │ "X"       │ "P"       │
# │ 196 │ "B"       │ "R"       │ "R"       │
# │ 197 │ "A"       │ "C"       │ "P"       │
# │ 198 │ "B"       │ "X"       │ "R"       │
# │ 199 │ "A"       │ "R"       │ "P"       │
# │ 200 │ "B"       │ "C"       │ "P"       │

# %%
tail(data, 3)
# Out:
# 3×10 DataFrames.DataFrame
# │ Row │ Patient │ Gender │ Age │ Variable1 │ Variable2 │ Variable3 │ Variable4 │
# ├─────┼─────────┼────────┼─────┼───────────┼───────────┼───────────┼───────────┤
# │ 1   │ 198     │ "M"    │ 49  │ 11.2      │ 95        │ 1.8       │ 53        │
# │ 2   │ 199     │ "M"    │ 36  │ 24.2      │ 97        │ 8.2       │ 58        │
# │ 3   │ 200     │ "F"    │ 48  │ 10.3      │ 114       │ 20.4      │ 63        │
#
# │ Row │ Category1 │ Category2 │ Category3 │
# ├─────┼───────────┼───────────┼───────────┤
# │ 1   │ "B"       │ "X"       │ "R"       │
# │ 2   │ "A"       │ "R"       │ "P"       │
# │ 3   │ "B"       │ "C"       │ "P"       │

# %%
showcols(data)
# Out:
# 200×10 DataFrames.DataFrame
# │ Col # │ Name      │ Eltype     │ Missing │
# ├───────┼───────────┼────────────┼─────────┤
# │ 1     │ Patient   │ Int64      │ 0       │
# │ 2     │ Gender    │ UTF8String │ 0       │
# │ 3     │ Age       │ Int64      │ 0       │
# │ 4     │ Variable1 │ Float64    │ 0       │
# │ 5     │ Variable2 │ Int64      │ 0       │
# │ 6     │ Variable3 │ Float64    │ 0       │
# │ 7     │ Variable4 │ Int64      │ 0       │
# │ 8     │ Category1 │ UTF8String │ 0       │
# │ 9     │ Category2 │ UTF8String │ 0       │
# │ 10    │ Category3 │ UTF8String │ 0       │

# %%
by(data, :Gender, d -> DataFrame(SampleSize = size(d, 1)))
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ Gender │ SampleSize │
# ├─────┼────────┼────────────┤
# │ 1   │ "F"    │ 100        │
# │ 2   │ "M"    │ 100        │

# %%
describe(data[:Age])
# Out:
# Summary Stats:
# Mean:         45.805000
# Minimum:      35.000000
# 1st Quartile: 40.000000
# Median:       46.000000
# 3rd Quartile: 52.000000
# Maximum:      55.000000

# %%
describe(data[:Category1])
# Out:
# Length  200
# Type    UTF8String
# NAs     0
# NA%     0.0%
# Unique  2
